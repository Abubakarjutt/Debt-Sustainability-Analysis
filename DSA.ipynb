# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns
from scipy.stats import spearmanr, pearsonr
# %matplotlib inline
data = pd.read_csv('C://Users/HP/Desktop/New folder/DSA.csv')
data.head()
# Out:
#    Year  ExternelDebt  %ExtDebt  ExtDebtService  %ExtDebtService  \
# 0  1980    9931198662  0.065407    8.687395e+08         0.059735
# 1  1981   10580767700  0.065407    9.206338e+08         0.059735
# 2  1982   11703994182  0.106157    8.846406e+08        -0.039096
# 3  1983   12026223274  0.027532    1.344928e+09         0.520310
# 4  1984   12227885012  0.016769    1.252984e+09        -0.068363
#
#    DomesticDebt   USDRate       DomDebt  %DomDebt  DomDebtService  ...  \
# 0   60838700000  25.12219  2.421712e+09 -0.028163       121085583  ...
# 1   59125300000  25.12219  2.353509e+09 -0.028163       117675450  ...
# 2   82883000000  25.12219  3.299195e+09  0.401820       164959744  ...
# 3  105362800000  25.12219  4.194013e+09  0.271223       209700668  ...
# 4  126870900000  25.12219  5.050153e+09  0.204134       252507645  ...
#
#             GDP      %GDP     Exports   %Export         TaxLC  USDRate.1  \
# ...

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(data.corr())

# %%
ExtDebt = data["%ExtDebt"]
GDP = data["%GDP"]
Year = data['Year']

x= data["%ExtDebt"]
y= data["%GDP"]


print("Corrilation: {}".format(pearsonr(x, y)))




plt.plot(Year,GDP)
plt.plot(Year,ExtDebt)



plt.legend()
# Out:
# Corrilation: (-0.027438989056884067, 0.868304630983157)

# %%
GDP = data["%GDP"]
Domestic_debt = data['%DomDebt']

x= data['%DomDebt']
y= data["%GDP"]

print("Corrilation: {}".format(pearsonr(x, y)))



plt.plot(Year,GDP)
plt.plot(Year,Domestic_debt)



plt.legend()
# Out:
# Corrilation: (0.03884244907390602, 0.8143893146085919)

# %%
ExtDebt = data["%ExtDebt"]
Exports = data["%Export"]

x= data["%ExtDebt"]
y= data["%Export"]

print("Corrilation: {}".format(pearsonr(x, y)))
plt.plot(Year,Exports)
plt.plot(Year,ExtDebt)



plt.legend()
# Out:
# Corrilation: (-0.04252372009112659, 0.7971505163949837)

# %%
Exports = data["%Export"]
DomesticDebt = data["%DomDebt"]

x= data["%DomDebt"]
y= data["%Export"]

print("Corrilation: {}".format(pearsonr(x, y)))
plt.plot(Year,Exports)
plt.plot(Year,DomesticDebt)



plt.legend()
# Out:
# Corrilation: (0.11999625816939505, 0.4668397811463768)
